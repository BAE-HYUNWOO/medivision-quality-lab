# %% [markdown]
# # Train PneumoniaMNIST ResNet18
#
# This notebook trains a ResNet18 classifier on PneumoniaMNIST.

# %%
# !pip install medmnist grad-cam scikit-learn opencv-python tqdm

# %%
from medmnist import INFO
print(INFO["pneumoniamnist"])

# %%
# !python -m ml.train --data-flag pneumoniamnist --size 224 --model-name resnet18 --epochs 8 --batch-size 32 --output-path models/pneumonia_resnet18_224.pt
