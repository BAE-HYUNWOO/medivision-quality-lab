# %% [markdown]
# # Error analysis
#
# Use this notebook to inspect incorrect predictions, confidence distribution, and confusion matrix.

# %%
# !python -m ml.evaluate --model-path models/pneumonia_resnet18_224.pt --data-flag pneumoniamnist --size 224 --model-name resnet18
