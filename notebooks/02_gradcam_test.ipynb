# %% [markdown]
# # Grad-CAM test
#
# Use this after training a checkpoint.

# %%
# !pip install grad-cam opencv-python

# %%
from ml.gradcam import save_gradcam_overlay
# save_gradcam_overlay("models/pneumonia_resnet18_224.pt", "path/to/image.png", "outputs/gradcam.png")
